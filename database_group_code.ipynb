# %%
import mysql.connector
import pandas as pd
import yfinance as yf

# %%
#create company class
class Company:

    def getCompanyName(self):
        return self._companyName
    def setCompanyName(self, companyName):
        self._companyName = companyName
    
    def getStockPrice(self):
        return self._stockPrice
    def setStockPrice(self, stockPrice):
        return self._stockPrice = stockPrice
    
    def getStockWeight(self):
        return self_stockWeight
    def setStockWeight(self, stockWeight):
        return self._stockWeight = stockWeight

    
#constructor for Company class
    def __init__(self, companyName = None, stockPrice = None, stockWeight = None):
        self.__companyName = companyName
        self.__stockPrice = stockPrice
        self.__stockWeight = stockWeight

#print method
    def printCompanyDetails(self):
        print("Name: " + str(self.__companyName))
        print("Stock Price: " + str(self.__stockPrice))
        print("Stock Weight: " + str(self.__stockWeight))

# %%
class CompanySQL:
    def __init__(self):
        pass
    def getCompanyData(self, name):
        try:
            connection = mysql.connector.connect(
                user="trjohnst_mis2100",
                password="ex(3y0#RiJsY",
                host="jdbc:mysql://trjohnst.mis.sbe.mtu.edu/trjohnst_MiniProject?user=trjohnst_mis2100&password=ex(3y0#RiJsY",
                database='trjohnst_MiniProject')
            
            query = "SELECT* FROM PortfolioData WHERE portfolio_name=?"
            cursor = connection.cursor(prepared=True)
            cursor.execute(query,(name,))
            ##does this do what we want it to right now?
            for(companyName, stockPrice, stockWeight) in cursor:
                print("{} at a stock price of {} has a current stock weight of {}".format(companyName, stockPrice, stockWeight))
            cursor.close()
            connection.close()
        except mysql.connector.Error as err:
             print(err)
                
    def insertCompany(self, ticker, company_name):
        try:
            connection = mysql.connector.connect(
                user="trjohnst_mis2100",
                password="ex(3y0#RiJsY",
                host="jdbc:mysql://trjohnst.mis.sbe.mtu.edu/trjohnst_MiniProject?user=trjohnst_mis2100&password=ex(3y0#RiJsY",
                database='trjohnst_MiniProject')
            query = "INSERT INTO Company (ticker, company_name) values(?, ?)"
            cursor = connection.cursor(prepared=True)
            cursor.execute(query,(ticker, company_name))
            cursor.close()
            connection.close()
        except mysql.connector.Error as err:
             print(err)
                
    def insertPortfolio(self, portfolio_name):
        try:
            connection = mysql.connector.connect(
                 user="trjohnst_mis2100",
                password="GSSRt+U.9f{6",
                host="jdbc:mysql://trjohnst.mis.sbe.mtu.edu/trjohnst_MiniProject?user=trjohnst_mis2100&password=GSSRt+U.9f{6",
                database='trjohnst_MiniProject')
            query ="INSERT INTO Portfolio (portfolio_name) values(?)"
            cursor = connection.cursor(prepared=True)
            cursor.execute(query,(portfolio_name,))
            cursor.close()
            connection.close()
        except mysql.connector.Error as err:
             print(err)
                
    def insertStock(self):
        try:
            connection = mysql.connector.connect(
                 user="trjohnst_mis2100",
                password="ex(3y0#RiJsY",
                host="jdbc:mysql://trjohnst.mis.sbe.mtu.edu/trjohnst_MiniProject?user=trjohnst_mis2100&password=ex(3y0#RiJsY",
                database='trjohnst_MiniProject')
            query = "INSERT INTO PortfolioData (portfolio_name, ticker, access_date, shares, stock_price, pe_ratio, beta, moving_average) values(?, ?, ?, ?, ?, ?, ?, ?)"
            cursor = connection.cursor(prepared=True)
            cursor.execute(query,(portfolio_name, ticker, access_date, shares, stock_price, pe_ratio, beta, moving_average,))
            cursor.close()
            connection.close()
        except mysql.connector.Error as err:
             print(err)

# %%
company = CompanySQL()
company.insertPortfolio("test")
# Out:
# ---------------------------------------------------------------------------
# UnicodeError                              Traceback (most recent call last)
# ~\Miniconda3\lib\encodings\idna.py in encode(self, input, errors)
#     166             if len(labels[-1]) >= 64:
# --> 167                 raise UnicodeError("label too long")
#     168             return result, len(input)
#
# UnicodeError: label too long
#
# The above exception was the direct cause of the following exception:
#
# UnicodeError                              Traceback (most recent call last)
# <ipython-input-17-01fcdac008bd> in <module>
#       1 company = CompanySQL()
# ----> 2 company.insertPortfolio("test")
#
# <ipython-input-16-9ab2f1b7187a> in insertPortfolio(self, portfolio_name)
#      42                 password="GSSRt+U.9f{6",
#      43                 host="jdbc:mysql://trjohnst.mis.sbe.mtu.edu/trjohnst_MiniProject?user=trjohnst_mis2100&password=ex(3y0#RiJsY",
# ---> 44                 database='trjohnst_MiniProject')
#      45             query ="INSERT INTO Portfolio (portfolio_name) values(?)"
#      46             cursor = connection.cursor(prepared=True)
#
# ~\Miniconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     175     if HAVE_CEXT and not use_pure:
#     176         return CMySQLConnection(*args, **kwargs)
# --> 177     return MySQLConnection(*args, **kwargs)
#     178 Connect = connect  # pylint: disable=C0103
#     179
#
# ~\Miniconda3\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#     102         if kwargs:
#     103             try:
# --> 104                 self.connect(**kwargs)
#     105             except:
#     106                 # Tidy-up underlying socket on failure
#
# ~\Miniconda3\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     779
#     780         self.disconnect()
# --> 781         self._open_connection()
#     782         # Server does not allow to run any other statement different from ALTER
#     783         # when user's password has been expired.
#
# ~\Miniconda3\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     282         self._socket = self._get_connection()
#     283         try:
# --> 284             self._socket.open_connection()
#     285             self._do_handshake()
#     286             self._do_auth(self._user, self._password,
#
# ~\Miniconda3\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     503                                            self.server_port,
#     504                                            0, socket.SOCK_STREAM,
# --> 505                                            socket.SOL_TCP)
#     506             # If multiple results we favor IPv4, unless IPv6 was forced.
#     507             for info in addrinfos:
#
# ~\Miniconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     746     # and socket type values to enum constants.
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#     750         addrlist.append((_intenum_converter(af, AddressFamily),
#
# UnicodeError: encoding with 'idna' codec failed (UnicodeError: label too long)

# %%
class Porfolio:
    def __init__(self, PortfolioList):
        self.comapanyTicker = companyTicker
        self.companyAsset = []

# %%
class CompanyAsset:
    def __init__ (self, stockPrice, stockWeight,sharesHeld, firstName, lastName, ID):
        self.stockPrice = stockPrice
        self.stockWeight = stockWeight
        self.sharesHeld = sharesHeld
        self.firstName = firstName
        self.lastName = lastName
        self.ID = ID

# %%
class YFinance:
    globalTick = ""
    def __init__(self):
        
        
    def setTicker(ticker):
        global globalTick
        globalTick = yf.Ticker(ticker)

    def stockInfo():
        global globalTick
        print(globalTick.info)

    def getHistory(timeframe):
        global globalTick
        print(globalTick.history(period=timeframe))
    
    def getOptions():
        global globalTick
        print(globalTick.options)
    
    def getActions():
        global globalTick
        print(globalTick.actions)

    while 1:
        print("Input a stock ticker: ")
        ticker = input()
        setTicker(ticker)
        stockInfo()
        print("Input a time frame (1d, 1mo, 1y, ytd): ")
        date = input()
        getHistory(date)
